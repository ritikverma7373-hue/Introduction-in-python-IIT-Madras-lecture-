# %% [markdown]
# <a href="https://colab.research.google.com/github/ritikverma7373-hue/Introduction-in-python-IIT-Madras-lecture-/blob/python-language/Lecture_18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # An Interesting  Cliper: More on Strings

# %%
alpha= 'abcdefghijklmnopqrstuvwxyz'
# The First indexing is start with 0
print(alpha[1])
i=10
print(alpha[i])
print(alpha[i+1])
print(alpha[i+2])
print(alpha[i+3])
print(alpha[i+4])
i=25
print(alpha[i])
print(alpha[i+1])
print(alpha[i+2])
print(alpha[i+3])
print(alpha[i+4])
# Out:
# b
# k
# l
# m
# n
# o
# z
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-3010764080.py in <cell line: 0>()
#      10 i=25
#      11 print(alpha[i])
# ---> 12 print(alpha[i+1])
#      13 print(alpha[i+2])
#      14 print(alpha[i+3])
#
# IndexError: string index out of range

# %% [markdown]
# If I were to do i equal 10, it will start from k as you can see and then go to Im n.
# The part part now is I say 25,it will start with z of course, alpha of 25 is zwell, you do not guessed it right, alpha of 26 will throw an error.Precisely what we see here; string out of range. Your alpha is only 26 letter long, which means you can go up to alpha of 0 to 25,i plus 1 becomes 26, alpha of 26 becomes out of range.For this we will use modulo operator (modulo (%)).

# %%
alpha='abcdefghijklmnopqrstuvwxyz'
i=25
print(alpha[i%26])
print(alpha[(i+1)%26])
print(alpha[(i+2)%26])
print(alpha[(i+3)%26])
print(alpha[(i+4)%26])
s='ritikverma'
#If you taking a string s and you all letter in string in 1 plus means 1 letter shifted in right it then,
# I expect to output sjvjlwfsnb when I was shifted 1 letter
print(s[0])
print(alpha.index(s[0]))
t=''
i=0
k=1
t=t+(alpha[(((alpha.index(s[i]))+k)%26)])
t=t+(alpha[(((alpha.index(s[i+1]))+k)%26)])
t=t+(alpha[(((alpha.index(s[i+2]))+k)%26)])
t=t+(alpha[(((alpha.index(s[i+3]))+k)%26)])
t=t+(alpha[(((alpha.index(s[i+4]))+k)%26)])
t=t+(alpha[(((alpha.index(s[i+5]))+k)%26)])
t=t+(alpha[(((alpha.index(s[i+6]))+k)%26)])
t=t+(alpha[(((alpha.index(s[i+7]))+k)%26)])
t=t+(alpha[(((alpha.index(s[i+8]))+k)%26)])
t=t+(alpha[(((alpha.index(s[i+9]))+k)%26)])
print(t)
#This is the popularly called the caeser cipher in cryptography
alpha='abcdefghijklmnopqrstuvwxyz'
s='indianinstitudeoftecnology'
#I expect output tvebstibo
t=''
i=0
k=1
t=t+(alpha[(((alpha.index(s[i]))+k)%26)])
t=t+(alpha[(((alpha.index(s[i+1]))+k)%26)])
t=t+(alpha[(((alpha.index(s[i+2]))+k)%26)])
t=t+(alpha[(((alpha.index(s[i+3]))+k)%26)])
t=t+(alpha[(((alpha.index(s[i+4]))+k)%26)])
t=t+(alpha[(((alpha.index(s[i+5]))+k)%26)])
t=t+(alpha[(((alpha.index(s[i+6]))+k)%26)])
t=t+(alpha[(((alpha.index(s[i+7]))+k)%26)])
t=t+(alpha[(((alpha.index(s[i+8]))+k)%26)])
t=t+(alpha[(((alpha.index(s[i+9]))+k)%26)])
print(t)
# i and k are variables where you put the literals and the use in a print statement.
# i is a what the index in string you should take and k is the value added in index.
# Out:
# z
# a
# b
# c
# d
# r
# 17
# sjujlwfsnb
# joejbojotu
