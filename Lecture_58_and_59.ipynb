# %% [markdown]
# <a href="https://colab.research.google.com/github/ritikverma7373-hue/Python-Basics-English-IIT-Madras-lecture-/blob/python-language/Lecture_58_and_59.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to the week and recursion

# %% [markdown]
# 1. Recursion
# 2. More programming
# 3. File Handling

# %% [markdown]
# # Recursion
# If you have a 10 vessels clean after the party.
# V(10):Clean 1 vessel left V(9)
# v(10)=1+V(9)
# A(n)=Something+A(n-1)
# Example: COVID is also a recursive
# So when does question is difficult the queation is on recursion.
