# %% [markdown]
# <a href="https://colab.research.google.com/github/ritikverma7373-hue/Python-Basics-English-IIT-Madras-lecture-/blob/python-language/Lecture_53.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Reading and writting a file
# . At the end of this lecture, you will be able to:
# .Read from a file and write to a file using python

# %%
# !pwd
f=open('mytext.txt','w')
f.write("ritik ")
f.write("yourname ")
f.write("IIT ")
f.close()
x=open('mytext.txt','r')
print(x.read())
print(type(x.read()))
x.close
print(x.read()) # it do not show anything because file is closed
# Out:
# /content
# ritik yourname IIT
# <class 'str'>

# %%
f=open("newfile.txt","w")
f.write("This is the first line ")
f.write("This is the second line ")
f.close()
f=open("newfile.txt","r")
print(f.read())
f.close()
# Out:
# This is the first line This is the second line
