# %% [markdown]
# <a href="https://colab.research.google.com/github/ritikverma7373-hue/Introduction-in-python-IIT-Madras-lecture-/blob/python-language/Lecture_45.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Types of functions

# %% [markdown]
# There are four types of function explained in this lecture

# %% [markdown]
# Inbuilt functions
#
# print(), input(), len()
#
# Library functions
#
# log(), sqrt(), random(), randrange(), calendar(), month()
#
# String methodsfunctions
#
# upper(), lower(), strip(), count(), index(), replace()
#
# user defined functions
#
# def square(x):
#  sqr = x**2
#  return sqr
# print(square(5))
