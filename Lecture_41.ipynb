# %% [markdown]
# <a href="https://colab.research.google.com/github/ritikverma7373-hue/Introduction-in-python-IIT-Madras-lecture-/blob/python-language/Lecture_41.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to Function

# %%
def add(a,b):
  ans=a+b
  print(ans)
add(1,6)
add(10,72)
def sub(a,b):
 ans=a+b
 print(ans)
sub(10,8)
add(8,9)
def discount(cost,d):
  ans=cost-(cost*(d/100))
  print(ans)
discount(100,8)
discount(1200,20)
#add(17,5)+sub(100,3)+discount(1500,7.5)
# error because unsuported operend type(s) for +: 'Nonetype' and 'Nonetype'
# Out:
# 7
# 82
# 18
# 17
# 92.0
# 960.0

# %% [markdown]
# But my functions that I have written is not doing that, simply because let me go up an dthen see what is happening here. I say, define add a comma b,I only print it. Is there any way I can return the sum of a and b of this function.

# %%
def discount(cost,d):
  ans=cost-(cost*(d/100))
  return ans
print("Enter the cost price:")
x=int(input())
print("Enter the discount:")
y=int(input())
print("The final discount is:",discount(x,y))
# Out:
# Enter the cost price
# 100
# Enter the discount
# 8
# The final discount is: 92.0
