# %% [markdown]
# <a href="https://colab.research.google.com/github/ritikverma7373-hue/Python-Basics-English-IIT-Madras-lecture-/blob/python-language/Lecture_54.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Big text file handling

# %% [markdown]
# # Let, if 231 Mb file text file contain mobile number.

# %% [markdown]
# To find the mobile number we use loop

# %%
f=open('directory.txt','r')
flag=0
s='0'
while():
  s=f.readline()
  if (s!=''):
    n=int(s)
  if (n=9020214917):
    print("Mobile number found")
    flag=1
    break
if (flag==0):
  print("Mobile number not found")
