# %% [markdown]
# <a href="https://colab.research.google.com/github/ritikverma7373-hue/Python-Basics-English-IIT-Madras-lecture-/blob/python-language/Lecture_55.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Very big files

# %% [markdown]
# 12 billion phone number it will take approximately 12 GB of data .
# if we find the phone number between them.

# %% [markdown]
# Irrespective of how big the fileis, tak ea big file, it may not open, but you can but you can go line by line of the file. I hope is clear to you. It might take a long time for it to finish, but it will never get hung. Why is that? That is because your file system.So, let me illustrate that,Your file system is like big tape this.It is a big tape. It will start seing what is begning of this second, third, fourth, fifth and so on like this, and so on . It can always go linerly in this fashion, in your file one after the another.go through one by one. That is the advantage of a big file.
