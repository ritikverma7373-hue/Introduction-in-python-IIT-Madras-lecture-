# %% [markdown]
# <a href="https://colab.research.google.com/github/ritikverma7373-hue/Introduction-in-python-IIT-Madras-lecture-/blob/python-language/Lecture_19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to the if statement

# %%
#if condition
# Let us consider the movie "Avengers".
print("Please enter your date of birth")

birth_year=int(input())
current_year=2026

age=current_year-birth_year

if (age<13):
   print("You are under age you cannot watch this movie")
   print("Wait until you are old enough to watch this movie")
else:
   print("You are old enough to watch this movie")
   print("Don't forget to watch the sequels and prequels")

print("Have a nice time")
# Out:
# Please enter your date of birth
# 2015
# You are under age you cannot watch this movie
# Wait until you are old enough to watch this movie
# Have a nice time

# %% [markdown]
# The both print statement under the if statement, the both print statement under the else statement.
# And the print statement ("Have a nice time"), outside the if and else statement, so any loop get executed but this print statement in both execution.
# And let me also try to tell you taht you can in fact write if statement within other if statement.
