# %% [markdown]
# <a href="https://colab.research.google.com/github/ritikverma7373-hue/Introduction-in-python-IIT-Madras-lecture-/blob/python-language/Lecture_42.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Functional programming inline statement and list compressions

# %%
# inline statement reduces the length of the code.
a=100
b=10
'''if a<b:
  small=a
else:
  small=b'''
small=q if a<b else b
print(small)
# Out:
# 10

# %%
# inline code for while loop
a=5
'''while a>0:
 print(a)
 a-=1'''
while a>0: print(a); a-=1
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
fruits =["mango","guava","kiwi","orange","grapes"]
'''newlist=[]
for fruit in fruits:
  if "n" in fruit:
    newlist.append(fruit.capitalize())
print(newlist)'''
newlist=[fruit.capitalize() for fruit in fruits if "n" in fruit]
print(newlist)
# Out:
# ['Mango', 'Orange']
