# %% [markdown]
# <a href="https://colab.research.google.com/github/ritikverma7373-hue/Introduction-in-python-IIT-Madras-lecture-/blob/python-language/Lecture_35.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Warmup with lists

# %%
l=[1,7,4,2,100]
print(l)
l.append(1024)
print(l)
l.append(2)
print(l)
l.remove(1)
print(l)
l.remove(2)
# It is obivious, but what I say remove 2?
# The number 2 is repeated twice here. So,possibility  one is,
# it will remove the first occurance of 2 or may be second occurence of 2
#  or may be it will remove both, So, let us see what it does.
print(l)
# Its remove the first occurance of 2.just in case, I typed it once again,
# it remove the second occurance of 2.
l.remove(2)
print(l)
# Out:
# [1, 7, 4, 2, 100]
# [1, 7, 4, 2, 100, 1024]
# [1, 7, 4, 2, 100, 1024, 2]
# [7, 4, 2, 100, 1024, 2]
# [7, 4, 100, 1024, 2]
# [7, 4, 100, 1024]

# %% [markdown]
# What I am now going to tell you is probly one of the most important ideas in data sciences. And what is that?That is a matrix and how do you represent matrices?
# what if I create another array x and then I append l to x?
#
# you see taht strange.Let me try doing that.Well, it accepted, there  was no error. So, whst is it even mean, I am appending, I am creating an array x and I am appending another array l to x. How does it look like? Let me print x and see it. You see it is an array and it contains another array.
# Let me create just for example, let us say m 10,20,30 and let me take x just the way I appended I into x, let me append m into x. Now when I say printx, it prints1,2,3,10,20,30.So, it is a list within a list. That is a very popular idiom in english called wheels within wheels. So,anyway you will get used to it.In fact, there is no limit here,you can have a list of a list of a list of a list,we can go up to infinity like that.So

# %%
l=[]
l.append(1)
l.append(2)
l.append(2)
print(l)
x=[]
x.append(l)
print(x)
m=[10,20,30]
x.append(m)
print(x)
t=[]
t.append(x)
print(t)
t.append([100,101,102])
print(t)
print(t[0])
print(t[1])
# Out:
# [1, 2, 2]
# [[1, 2, 2]]
# [[1, 2, 2], [10, 20, 30]]
# [[[1, 2, 2], [10, 20, 30]]]
# [[[1, 2, 2], [10, 20, 30]], [100, 101, 102]]
# [[1, 2, 2], [10, 20, 30]]
# [100, 101, 102]

# %% [markdown]
# I will print M, capital M and I  get 1,2,3,4,5,6,7,8,9 and this is how I am going to treating a matrix I mean, this is how I am going to store a matrix using lists.M of 0 will be so much and M of is a list containing 1,2,3 and in that list I can see the first element which is 1.In that list I can say the second element which is M of 0 comma 1, you see in matrices we would write a subscript ij, aij,a11,a12,a13 etc.

# %%
M=[]
M.append([1,2,2])
M.append([4,5,6])
M.append([7,8,9])
print(M[0])
print(M[0][0])
print(M[0][1])
print(M[0][2])
print(M[1][0])
print(M[1][1])
print(M[1][2])
# Out:
# [1, 2, 2]
# 1
# 2
# 2
# 4
# 5
# 6

# %% [markdown]
# So go ahead, open your terminal, start typing your qwn programs, play around with lists.
