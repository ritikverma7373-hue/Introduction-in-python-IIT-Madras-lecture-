# %% [markdown]
# <a href="https://colab.research.google.com/github/ritikverma7373-hue/Introduction-in-python-IIT-Madras-lecture-/blob/python-language/lecture_15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lecture 15

# %% [markdown]
# # variables revisited: Dynamic Typing

# %%
# We are typing to illustrate what we call the dynamic typing
a=10
print(type(a))
# Out:
# <class 'int'>

# %%
a='INDIA'
print(type(a))
# Out:
# <class 'str'>

# %% [markdown]
# Remmember, we were discussing about the jar in your kitchen.
# you can use the jar to store rice or maybe even water for that matter,but then specialize in our, in the containers taht we use for storage, we do not use the same container is used to store rice, we do not use that to store milk,Milk container looks likes different.so similarly, a computer tries to store an integer type using a different kind of memory location.Moment you say equals 10, It creates a particular data type, I mean the memory location where it,where the value of (A) is stored and the moment you say A equals India, of course, it loses the value of 10 that is initially assigned to, but then it becomes of type string.
# This is this goes by the name (dynamic typing)

# %%
n=10
print(type(n))
print(n)
n=n/1
# integer is int, float is a real number, in python
print(type(n))
print(n)
# Out:
# <class 'int'>
# 10
# <class 'float'>
# 10.0

# %% [markdown]
# The movement divison happens, it realizes that oh now the integer might become a non-integer; it cab become a rational or real number.So let us what is happens? What does Python do even if we divide by 1,Python makes the variable float from it being int.irrespective of you assigning explicitly you did not do n equals a string, you just divided n by 1, still Python was intelligent enough to now change the type to float thinking oh, this chap is doing some division, he may continue to do more division.Let me try making it float to be on the safer side.
